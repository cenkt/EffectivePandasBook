# %%
library("tswge")
data(dfw.mon)

# %%
write.csv(dfw.mon, file = "dfw.mon.csv", row.names = FALSE)

# %%
set.seed(8327)
x <- rep(0, 30)
for (i in 1:30) {
    roll <- sample(1:6, 2)
    x[i] <- roll[1] + roll[2]
}
plotts.wge(x)
abline(h = 7)
# Out:
# Plot with title ""

# %%
plotts.sample.wge(x)
# Out:
# $xbar
# [1] 7.833333
#
# $autplt
#  [1]  1.000000000 -0.099801882 -0.314016840  0.171619614 -0.182268450
#  [6] -0.088905399  0.028231798  0.105250124  0.220901436 -0.006686478
# [11] -0.125804854 -0.068103021  0.081723626 -0.116146607 -0.031698861
# [16]  0.219167905 -0.225359089 -0.149826647  0.231797920 -0.117632491
# [21]  0.011391778  0.043833581 -0.085685983  0.038880634 -0.044576523
# [26] -0.043338286
#
# $freq
#  [1] 0.03333333 0.06666667 0.10000000 0.13333333 0.16666667 0.20000000
#  [7] 0.23333333 0.26666667 0.30000000 0.33333333 0.36666667 0.40000000
# [13] 0.43333333 0.46666667 0.50000000
#
# $dbz
#  [1] -3.9633220 -2.4531058 -1.0416154 -0.2390095  0.0444041  0.3123077
#  [7]  0.9288868  1.6720190  2.1590620  2.1987880  1.7008194  0.5781392
# [13] -1.1962022 -3.3021901 -4.4282482
# plot without title
